# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"   
os.environ["CUDA_VISIBLE_DEVICES"]="2,3"

# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys


PROJECT_ROOT = os.getcwd()
if os.path.basename(PROJECT_ROOT) == "notebooks_causal_cactus":
    PROJECT_ROOT = os.path.dirname(PROJECT_ROOT)
os.chdir(PROJECT_ROOT)
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

from src.DataReaders import *
from src.address import *
from src.modelGen import *
from src.utils import cf_eval, cleanup_gpu, LOF_context_score
from models import CF_CausalCondLatentCF, CF_LatentCFpp, CF_PrototypeCF, CF_CondLatentCF
import numpy as np
import random 
from tensorflow import random as tf_random
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from itertools import product
import argparse
import pandas as pd
import tensorflow as tf
# Out:
# 2026-06-16 17:44:47.508848: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
SEED = 24

os.environ["PYTHONHASHSEED"] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf_random.set_seed(SEED)


CF_METHODS = {  
    "LatentCFpp": CF_LatentCFpp,
    "Prototype": CF_PrototypeCF,
    "CausalCACTUS": CF_CausalCondLatentCF,
    "CACTUS": CF_CondLatentCF
}

# %%
# Experimentos a realizar
EXP_CONFIG_PATH = os.path.join(PROJECT_ROOT, "configs", "experiments", "LAW_EXP.json")
with open(EXP_CONFIG_PATH, encoding="utf-8") as f:
    EXP = json.load(f)

# %%
# Loading data
CLASS_CONFIG_PATH = EXP[0]["classifier"]
class_config = get_exp_config(CLASS_CONFIG_PATH)
data   = getData(class_config)

# Getting the classifier
classifier = modelGen(class_config["type"], data,params=class_config, debug=True)
classifier.load()
# Out:
# /home/diego/repositorios/tabular-causal-counterfactuals/src/DataReaders/DataReader_Law.py:101: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   print(pd.value_counts(self.context["male"]))
# /home/diego/repositorios/tabular-causal-counterfactuals/src/DataReaders/DataReader_Law.py:102: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   print(pd.value_counts(self.context["racetxt"]))
# 2026-06-16 17:44:55.175779: E tensorflow/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2026-06-16 17:44:55.175801: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: Aegon
# 2026-06-16 17:44:55.175806: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: Aegon
# 2026-06-16 17:44:55.175917: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:200] libcuda reported version is: 595.71.5
# 2026-06-16 17:44:55.175935: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:204] kernel reported version is: 595.71.5
# 2026-06-16 17:44:55.175939: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:310] kernel version seems to match DSO: 595.71.5
# 2026-06-16 17:44:55.176069: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# male
# 1    10550
# 0     8142
# Name: count, dtype: int64
# racetxt
# 1    17491
# 0     1201
# Name: count, dtype: int64
#
#
#
#
# ----------------------------------------------------------------------------------------------------
# ---- DATA SUMMARY ----
# Total samples: 3672
# Positive class: 1836.0
# Context 'sex=Male': 1992
# Context 'race=White': 3138
# ----------------------------------------------------------------------------------------------------
#
#
#
#
# Building model
# Building model: Classifier_DNN [class]
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  main_input (InputLayer)     [(None, 9)]               0
#
#  dense (Dense)               (None, 64)                640
#
#  batch_normalization (BatchN  (None, 64)               256
#  ormalization)
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 128)               8320
#
#  batch_normalization_1 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 128)               16512
#
#  batch_normalization_2 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  batch_normalization_3 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 35,394
# Trainable params: 34,626
# Non-trainable params: 768
# _________________________________________________________________
# restoring weights of model Classifier_DNN: LAW_class

# %%
# Select test data
X_test = data.X_test
y_test_onehot = data.y_test
context_test = data.context_test

context_labels = ["non-white","white"]

X_original = []
y_original_onehot = []
context_original = []

N = 5
SELECTED_IDX = []

for val, lbl in enumerate(context_labels):
    idx = np.argwhere(context_test["racetxt"].values == val)[:,0]
    idx = np.random.choice(idx, N)

    SELECTED_IDX += idx.tolist()

    X_original.append(X_test[idx])
    y_original_onehot.append(y_test_onehot[idx])
    context_original.append(context_test.values[idx])

X_original = np.vstack(X_original)
y_original_onehot = np.vstack(y_original_onehot)
context_original = np.vstack(context_original)

lof_original = LOF_context_score(
    data.X_train,
    data.context_train.values,
    X_original,
    context_original,
    agg=False
)

# %%
import re
from collections import defaultdict
# TODO: make a function to convert the causal paths for all the test samples
def build_causal_index_map(input_features, graph_str):
    """
    Returns:
        child_to_parents: dict {child_idx: [parent_idx, ...]}
        parent_to_children: dict {parent_idx: [child_idx, ...]}
        feat2idx: dict {feature_name: index}
    """

    # Feature name to index
    feat2idx = {f: i for i, f in enumerate(input_features)}

    # Extract edges using regex
    edges = re.findall(r'(\w+)\s*->\s*(\w+)', graph_str)

    child_to_parents = defaultdict(list)
    parent_to_children = defaultdict(list)

    for parent, child in edges:

        if parent not in feat2idx or child not in feat2idx:
            raise ValueError(f"Feature in graph not found in dataset: {parent} or {child}")

        p_idx = feat2idx[parent]
        c_idx = feat2idx[child]

        child_to_parents[c_idx].append(p_idx)
        parent_to_children[p_idx].append(c_idx)

    return dict(child_to_parents), dict(parent_to_children), feat2idx




# 
graph_str2 = """ 
strict digraph {
fulltime;
zgpa;
zfygpa;
faminc;
decile1b;
racetxt;
male;
ugpa;
decile3;
lsat;
tier;
fulltime -> faminc;
ugpa -> decile3;
lsat -> decile1b;
}
"""

# %%
SEED = 13

os.environ['PYTHONHASHSEED'] = str(SEED)
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

#########
# Context-preserving CF generation
#########
X_cf_list = []
y_cf_labels_list = []
X_internal_list = []
y_internal_list = []
lof_cf_list = []
cf_scores_list = []
cf_scores_labels_list = []

for exp_id, exp in enumerate(EXP):

    AE_CONFIG_PATH = exp["AEmodel"]
    AE_config = get_exp_config(AE_CONFIG_PATH)

    ae_model = modelGen(
        AE_config["type"],
        data,
        params=AE_config,
        debug=True
    )
    ae_model.load()

    y_original_labels = np.argmax(y_original_onehot, axis=1)
    y_original_logits = classifier.predict(X_original)

    # NOTE: updated
    child_to_parents_dict, parent_to_children_dict, feat2idx = build_causal_index_map(
        data.features_lbls,
        graph_str2
    )
    print("Feature → index:")
    print(feat2idx)
    print("\nChild → Parents (index form):")
    print(child_to_parents_dict)

    if exp["name"] == "CausalCACTUS":
        CF_method = CF_METHODS[exp["CFmethod"]](
            classifier=classifier,
            # gen=aeModel,
            gen=ae_model,
            params=exp,
            x=data.X_train,
            y=data.y_train,
            x_min=data.X_train.min(axis=0),
            x_max=data.X_train.max(axis=0),
            causal_index_map=child_to_parents_dict
        )
    else:
        CF_method = CF_METHODS[exp["CFmethod"]](
            classifier=classifier,
            # gen=aeModel,
            gen=ae_model,
            params=exp,
            x=data.X_train,
            y=data.y_train
        )

    X_cf, y_cf_labels, X_internal, y_internal = CF_method.transform(
        X_original,
        y_original_labels,
        target_context=context_original
    )

    lof_cf = LOF_context_score(
        data.X_train,
        data.context_train.values,
        X_cf,
        context_original,
        agg=False
    )
    
    # --- CF evaluation ---
    cf_scores, cf_scores_labels = cf_eval(
        X_train=data.X_train, # previous name: data.X_train
        context_train=data.context_train, # previous name: context_training,
        X=X_internal, # previous name: x,
        CF_X=X_cf, # previous name: cf_x, 
        pred_labels=y_original_labels, # previous name: y_,
        target_context=context_original, # previous name: context,
        CF_labels=y_cf_labels, # previous name: cf_y_
        X_unscaled=data.scaler_inverse_transform(X_internal),
        CF_X_unscaled=data.scaler_inverse_transform(X_cf),
        child_to_parents_dict=child_to_parents_dict,
        average=False
    )

    # X_cf = data.scaler_inverse_transform(X_cf) # TODO: non scale

    X_cf_list.append(X_cf)
    y_cf_labels_list.append(y_cf_labels)
    X_internal_list.append(X_internal)
    y_internal_list.append(y_internal)
    lof_cf_list.append(lof_cf)
    cf_scores_list.append(cf_scores)
    cf_scores_labels_list.append(cf_scores_labels)

    cleanup_gpu()
# Out:
# Building model
# Building model: AE_TABULAR [gen]
# Model: "model_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  main_input (InputLayer)     [(None, 9)]               0
#
#  model_5 (Functional)        (None, 16)                4672
#
#  model_6 (Functional)        (None, 9)                 4665
#
# =================================================================
# Total params: 9,337
# Trainable params: 9,337
# Non-trainable params: 0
# _________________________________________________________________
# restoring weights of model AE_TABULAR: LAW_AE
# 1/1 [==============================] - 0s 29ms/step
# Feature → index:
# {'lsat': 0, 'ugpa': 1, 'zfygpa': 2, 'zgpa': 3, 'faminc': 4, 'decile1b': 5, 'decile3': 6, 'fulltime': 7, 'tier': 8}
#
# Child → Parents (index form):
# {4: [7], 6: [1], 5: [0]}
# Building model: latentCF [CF]
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  z_input (InputLayer)        [(None, 16)]              0
#
#  model_6 (Functional)        (None, 9)                 4665
#
#  model (Functional)          (None, 2)                 35394
#
# =================================================================
# Total params: 40,059
# Trainable params: 39,291
# Non-trainable params: 768
# _________________________________________________________________
# Generating CF 0/10
# /home/diego/anaconda/yes/envs/cactus-env/lib/python3.10/site-packages/keras/initializers/initializers_v2.py:120: UserWarning: The initializer VarianceScaling is unseeded and being called multiple times, which will return identical values  each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
# /home/diego/anaconda/yes/envs/cactus-env/lib/python3.10/site-packages/keras/initializers/initializers_v2.py:120: UserWarning: The initializer RandomNormal is unseeded and being called multiple times, which will return identical values  each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
# epoch 1/100 Target [0.5] Target cls 1 	 Loss tol. 0.001
# Pred logit [0.97508675 0.02491326]   Pred 0  Loss 0.24070686101913452
#  Grad. abs/mean: 0.01/-0.00  Grad. min/max: -0.02/0.01
#
# epoch 2/100 Target [0.5] Target cls 1 	 Loss tol. 0.001
# Pred logit [0.9209672  0.07903279]   Pred 0  Loss 0.22570741176605225
#  Grad. abs/mean: 0.01/-0.00  Grad. min/max: -0.04/0.02
#
# epoch 3/100 Target [0.5] Target cls 1 	 Loss tol. 0.001
# Pred logit [0.7758385  0.22416146]   Pred 0  Loss 0.1772134006023407
#  Grad. abs/mean: 0.07/-0.00  Grad. min/max: -0.15/0.13
#
# epoch 4/100 Target [0.5] Target cls 1 	 Loss tol. 0.001
# Pred logit [0.61897093 0.38102904]   Pred 0  Loss 0.07608690857887268
#  Grad. abs/mean: 0.07/-0.00  Grad. min/max: -0.14/0.10
#
# epoch 5/100 Target [0.5] Target cls 1 	 Loss tol. 0.001
# Pred logit [0.5842079  0.41579217]   Pred 0  Loss 0.014154089614748955
#  Grad. abs/mean: 0.04/-0.00  Grad. min/max: -0.06/0.06
#
# epoch 6/100 Target [0.5] Target cls 1 	 Loss tol. 0.001
# Pred logit [0.5962464 0.4037536]   Pred 0  Loss 0.00709095923230052
#  Grad. abs/mean: 0.02/0.00  Grad. min/max: -0.04/0.04
#
# epoch 7/100 Target [0.5] Target cls 1 	 Loss tol. 0.001
# Pred logit [0.5461867 0.4538133]   Pred 0  Loss 0.00926336832344532
#  Grad. abs/mean: 0.03/0.00  Grad. min/max: -0.07/0.06
#
# epoch 8/100 Target [0.5] Target cls 1 	 Loss tol. 0.001
# Pred logit [0.4790635 0.5209365]   Pred 1  Loss 0.0021332099568098783
#  Grad. abs/mean: 0.01/0.00  Grad. min/max: -0.03/0.03
#
# Generating CF 1/10
# epoch 1/100 Target [0.5] Target cls 1 	 Loss tol. 0.001
# Pred logit [0.80341685 0.19658314]   Pred 0  Loss 0.13830998539924622
#  Grad. abs/mean: 0.06/-0.02  Grad. min/max: -0.14/0.08
#
# epoch 2/100 Target [0.5] Target cls 1 	 Loss tol. 0.001
# Pred logit [0.7225187  0.27748138]   Pred 0  Loss 0.09206178039312363
#  Grad. abs/mean: 0.05/-0.01  Grad. min/max: -0.13/0.06
#
# epoch 3/100 Target [0.5] Target cls 1 	 Loss tol. 0.001
# Pred logit [0.6948609  0.30513906]   Pred 0  Loss 0.0495145358145237
#  Grad. abs/mean: 0.03/0.00  Grad. min/max: -0.05/0.06
#
# epoch 4/100 Target [0.5] Target cls 1 	 Loss tol. 0.001
# Pred logit [0.55091614 0.44908392]   Pred 0  Loss 0.037970785051584244
#  Grad. abs/mean: 0.03/0.00  Grad. min/max: -0.07/0.07
#
# epoch 5/100 Target [0.5] Target cls 1 	 Loss tol. 0.001
# Pred logit [0.36547363 0.63452643]   Pred 1  Loss 0.0025924467481672764
#  Grad. abs/mean: 0.02/-0.00  Grad. min/max: -0.04/0.04
#
# Generating CF 2/10
# epoch 1/100 Target [0.5] Target cls 1 	 Loss tol. 0.001
# Pred logit [0.86972165 0.13027835]   Pred 0  Loss 0.16323693096637726
#  Grad. abs/mean: 0.05/0.00  Grad. min/max: -0.11/0.08
#
# epoch 2/100 Target [0.5] Target cls 1 	 Loss tol. 0.001
# Pred logit [0.8594642 0.1405358]   Pred 0  Loss 0.13669410347938538
#  Grad. abs/mean: 0.03/0.01  Grad. min/max: -0.07/0.06
#
# epoch 3/100 Target [0.5] Target cls 1 	 Loss tol. 0.001
# Pred logit [0.8291516  0.17084844]   Pred 0  Loss 0.12921451032161713
#  Grad. abs/mean: 0.05/0.01  Grad. min/max: -0.10/0.13
#
# epoch 4/100 Target [0.5] Target cls 1 	 Loss tol. 0.001
# Pred logit [0.77454656 0.22545347]   Pred 0  Loss 0.10834075510501862
#  Grad. abs/mean: 0.03/0.01  Grad. min/max: -0.08/0.07
#
# epoch 5/100 Target [0.5] Target cls 1 	 Loss tol. 0.001
# Pred logit [0.68419987 0.3158001 ]   Pred 0  Loss 0.07537580281496048
#  Grad. abs/mean: 0.05/0.02  Grad. min/max: -0.06/0.10
#
# epoch 6/100 Target [0.5] Target cls 1 	 Loss tol. 0.001
# Pred logit [0.6084529  0.39154705]   Pred 0  Loss 0.033929601311683655
#  Grad. abs/mean: 0.05/0.02  Grad. min/max: -0.06/0.13
#
# epoch 7/100 Target [0.5] Target cls 1 	 Loss tol. 0.001
# Pred logit [0.59095323 0.40904683]   Pred 0  Loss 0.011762041598558426
#  Grad. abs/mean: 0.02/0.00  Grad. min/max: -0.03/0.04
#
# epoch 8/100 Target [0.5] Target cls 1 	 Loss tol. 0.001
# Pred logit [0.5981233  0.40187663]   Pred 0  Loss 0.00827247928828001
#  Grad. abs/mean: 0.02/-0.00  Grad. min/max: -0.04/0.04
#
# epoch 9/100 Target [0.5] Target cls 1 	 Loss tol. 0.001
# Pred logit [0.5801093  0.41989064]   Pred 0  Loss 0.009628196246922016
#  Grad. abs/mean: 0.02/-0.01  Grad. min/max: -0.04/0.04
#
# epoch 10/100 Target [0.5] Target cls 1 	 Loss tol. 0.001
# Pred logit [0.5519983  0.44800168]   Pred 0  Loss 0.006417509168386459
#  Grad. abs/mean: 0.02/-0.00  Grad. min/max: -0.03/0.04
#
# epoch 11/100 Target [0.5] Target cls 1 	 Loss tol. 0.001
# Pred logit [0.5370022 0.4629978]   Pred 0  Loss 0.0027038250118494034
#  Grad. abs/mean: 0.01/-0.00  Grad. min/max: -0.02/0.03
#
# epoch 12/100 Target [0.5] Target cls 1 	 Loss tol. 0.001
# Pred logit [0.5258268  0.47417322]   Pred 0  Loss 0.0013691632775589824
#  Grad. abs/mean: 0.01/-0.00  Grad. min/max: -0.02/0.02
#
# epoch 13/100 Target [0.5] Target cls 1 	 Loss tol. 0.001
# Pred logit [0.5202847 0.4797153]   Pred 0  Loss 0.0006670226575806737
#  Grad. abs/mean: 0.01/-0.00  Grad. min/max: -0.02/0.01
#
# epoch 14/100 Target [0.5] Target cls 1 	 Loss tol. 0.001
# Pred logit [0.50021714 0.49978286]   Pred 0  Loss 0.0004114695475436747
#  Grad. abs/mean: 0.01/-0.00  Grad. min/max: -0.01/0.01
#
# epoch 15/100 Target [0.5] Target cls 1 	 Loss tol. 0.001
# Pred logit [0.48717928 0.5128208 ]   Pred 1  Loss 4.714965839980323e-08
#  Grad. abs/mean: 0.00/-0.00  Grad. min/max: -0.00/0.00
#
# Generating CF 3/10
# Generating CF 4/10
# epoch 1/100 Target [0.5] Target cls 1 	 Loss tol. 0.001
# Pred logit [0.6905498  0.30945024]   Pred 0  Loss 0.1067509800195694
#  Grad. abs/mean: 0.09/0.02  Grad. min/max: -0.23/0.16
#
# epoch 2/100 Target [0.5] Target cls 1 	 Loss tol. 0.001
# Pred logit [0.50895685 0.49104324]   Pred 0  Loss 0.03630921244621277
#  Grad. abs/mean: 0.07/0.02  Grad. min/max: -0.15/0.13
#
# epoch 3/100 Target [0.5] Target cls 1 	 Loss tol. 0.001
# Pred logit [0.444053 0.555947]   Pred 1  Loss 8.02235517767258e-05
#  Grad. abs/mean: 0.00/0.00  Grad. min/max: -0.00/0.01
#
# Generating CF 5/10
# epoch 1/100 Target [0.5] Target cls 0 	 Loss tol. 0.001
# Pred logit [0.5224141  0.47758594]   Pred 0  Loss 0.022238776087760925
#  Grad. abs/mean: 0.05/0.00  Grad. min/max: -0.09/0.09
#
# Generating CF 6/10
# epoch 1/100 Target [0.5] Target cls 1 	 Loss tol. 0.001
# Pred logit [0.91993374 0.08006623]   Pred 0  Loss 0.2149147391319275
#  Grad. abs/mean: 0.03/-0.00  Grad. min/max: -0.07/0.05
#
# epoch 2/100 Target [0.5] Target cls 1 	 Loss tol. 0.001
# Pred logit [0.78325695 0.21674313]   Pred 0  Loss 0.1763443648815155
#  Grad. abs/mean: 0.06/-0.01  Grad. min/max: -0.15/0.10
#
# epoch 3/100 Target [0.5] Target cls 1 	 Loss tol. 0.001
# Pred logit [0.6623036 0.3376964]   Pred 0  Loss 0.08023446798324585
#  Grad. abs/mean: 0.07/-0.00  Grad. min/max: -0.16/0.13
#
# epoch 4/100 Target [0.5] Target cls 1 	 Loss tol. 0.001
# Pred logit [0.5038386  0.49616137]   Pred 0  Loss 0.02634245716035366
#  Grad. abs/mean: 0.05/0.01  Grad. min/max: -0.08/0.10
#
# epoch 5/100 Target [0.5] Target cls 1 	 Loss tol. 0.001
# Pred logit [0.40557435 0.5944257 ]   Pred 1  Loss 1.4735069271409884e-05
#  Grad. abs/mean: 0.00/0.00  Grad. min/max: -0.00/0.00
#
# Generating CF 7/10
# Generating CF 8/10
# epoch 1/100 Target [0.5] Target cls 0 	 Loss tol. 0.001
# Pred logit [0.40029082 0.59970915]   Pred 1  Loss 0.08246181160211563
#  Grad. abs/mean: 0.06/0.02  Grad. min/max: -0.09/0.16
#
# epoch 2/100 Target [0.5] Target cls 0 	 Loss tol. 0.001
# Pred logit [0.5735854  0.42641464]   Pred 0  Loss 0.009941921569406986
#  Grad. abs/mean: 0.05/0.02  Grad. min/max: -0.11/0.14
#
# Generating CF 9/10
# epoch 1/100 Target [0.5] Target cls 0 	 Loss tol. 0.001
# Pred logit [0.57804817 0.4219518 ]   Pred 0  Loss 0.021787729114294052
#  Grad. abs/mean: 0.06/-0.00  Grad. min/max: -0.14/0.15
#
# Building model
# Building model: AE_TABULAR [gen]
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  main_input (InputLayer)     [(None, 9)]               0
#
#  model (Functional)          (None, 16)                4672
#
#  model_1 (Functional)        (None, 9)                 4665
#
# =================================================================
# Total params: 9,337
# Trainable params: 9,337
# Non-trainable params: 0
# _________________________________________________________________
# restoring weights of model AE_TABULAR: LAW_AE
# 1/1 [==============================] - 0s 29ms/step
# Feature → index:
# {'lsat': 0, 'ugpa': 1, 'zfygpa': 2, 'zgpa': 3, 'faminc': 4, 'decile1b': 5, 'decile3': 6, 'fulltime': 7, 'tier': 8}
#
# Child → Parents (index form):
# {4: [7], 6: [1], 5: [0]}
# Building model: CF_PrototypeCF [CF]
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.iter
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.decay
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.learning_rate
# WARNING:tensorflow:AutoGraph could not transform <bound method CF_PrototypeCF._loss of <tensorflow.python.eager.function.TfMethodTarget object at 0x7afa786a5870>> and will run it as-is.
# Cause: mangled names are not yet supported
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method CF_PrototypeCF._loss of <tensorflow.python.eager.function.TfMethodTarget object at 0x7afa786a5870>> and will run it as-is.
# Cause: mangled names are not yet supported
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# /home/diego/anaconda/yes/envs/cactus-env/lib/python3.10/site-packages/keras/initializers/initializers_v2.py:120: UserWarning: The initializer VarianceScaling is unseeded and being called multiple times, which will return identical values  each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
# /home/diego/anaconda/yes/envs/cactus-env/lib/python3.10/site-packages/keras/initializers/initializers_v2.py:120: UserWarning: The initializer RandomNormal is unseeded and being called multiple times, which will return identical values  each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(
# Epoch 0/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: False  c: 1.0
# L_pred: 1.00  L_dist: 112.23  L_AE: 0.00  L_proto: 81718.92  Loss: 1964.97
# Grad abs/mean: 464.99/-154.67  Grad min/max: -1000.00/446.72
#
# Epoch 1/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: False  c: 1.0
# L_pred: 1.00  L_dist: 176.42  L_AE: 0.00  L_proto: 6224.94  Loss: 81829.22
# Grad abs/mean: 991.71/-102.82  Grad min/max: -1000.00/1000.00
#
# Epoch 2/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: False  c: 1.0
# L_pred: 1.00  L_dist: 110.29  L_AE: 0.00  L_proto: 6667.93  Loss: 6398.53
# Grad abs/mean: 405.57/124.58  Grad min/max: -371.21/811.36
#
# Epoch 3/100   Target cls 1
# Pred logit: [0.01,0.99] Best proto: True  c: 1.0
# L_pred: 0.00  L_dist: 111.61  L_AE: 0.00  L_proto: 14257.92  Loss: 6776.52
# Grad abs/mean: 548.61/38.13  Grad min/max: -758.55/899.56
#
# Epoch 4/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 136.92  L_AE: 0.00  L_proto: 13269.79  Loss: 14366.74
# Grad abs/mean: 701.45/-8.40  Grad min/max: -1000.00/1000.00
#
# Epoch 5/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 0.99  L_dist: 131.22  L_AE: 0.00  L_proto: 8336.83  Loss: 13404.50
# Grad abs/mean: 680.19/234.49  Grad min/max: -1000.00/1000.00
#
# Epoch 6/100   Target cls 1
# Pred logit: [0.00,1.00] Best proto: True  c: 1.0
# L_pred: 0.00  L_dist: 174.18  L_AE: 0.00  L_proto: 8055.45  Loss: 8465.79
# Grad abs/mean: 597.21/-65.71  Grad min/max: -1000.00/849.57
#
# Epoch 7/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 125.86  L_AE: 0.00  L_proto: 7897.69  Loss: 8225.93
# Grad abs/mean: 603.27/-22.47  Grad min/max: -1000.00/1000.00
#
# Epoch 8/100   Target cls 1
# Pred logit: [0.00,1.00] Best proto: True  c: 1.0
# L_pred: 0.00  L_dist: 207.43  L_AE: 0.00  L_proto: 16191.62  Loss: 8021.54
# Grad abs/mean: 648.58/-126.13  Grad min/max: -1000.00/1000.00
#
# Epoch 9/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 120.09  L_AE: 0.00  L_proto: 7479.19  Loss: 16394.85
# Grad abs/mean: 704.65/-2.85  Grad min/max: -1000.00/1000.00
#
# Epoch 10/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 94.51  L_AE: 0.00  L_proto: 12513.23  Loss: 7597.32
# Grad abs/mean: 398.06/-141.50  Grad min/max: -918.64/408.30
#
# Epoch 11/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 174.41  L_AE: 0.00  L_proto: 6128.03  Loss: 12606.19
# Grad abs/mean: 720.21/111.89  Grad min/max: -1000.00/1000.00
#
# Epoch 12/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 0.99  L_dist: 106.09  L_AE: 0.00  L_proto: 13342.22  Loss: 6299.64
# Grad abs/mean: 331.62/-153.11  Grad min/max: -782.48/349.00
#
# Epoch 13/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 106.31  L_AE: 0.00  L_proto: 5329.75  Loss: 13446.66
# Grad abs/mean: 639.60/542.40  Grad min/max: -222.86/1000.00
#
# Epoch 14/100   Target cls 1
# Pred logit: [0.99,0.01] Best proto: True  c: 1.0
# L_pred: 0.99  L_dist: 57.92  L_AE: 0.00  L_proto: 17232.09  Loss: 5434.30
# Grad abs/mean: 284.53/-155.75  Grad min/max: -720.15/390.73
#
# Epoch 15/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 186.06  L_AE: 0.00  L_proto: 8354.98  Loss: 17289.14
# Grad abs/mean: 728.54/-137.26  Grad min/max: -1000.00/1000.00
#
# Epoch 16/100   Target cls 1
# Pred logit: [0.26,0.74] Best proto: True  c: 1.0
# L_pred: 0.00  L_dist: 123.09  L_AE: 0.00  L_proto: 27450.61  Loss: 8538.19
# Grad abs/mean: 673.68/20.09  Grad min/max: -1000.00/898.27
#
# Epoch 17/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 166.74  L_AE: 0.00  L_proto: 12944.78  Loss: 27570.62
# Grad abs/mean: 842.56/-115.56  Grad min/max: -978.23/1000.00
#
# Epoch 18/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 0.99  L_dist: 134.48  L_AE: 0.00  L_proto: 10629.38  Loss: 13108.89
# Grad abs/mean: 749.53/282.58  Grad min/max: -1000.00/1000.00
#
# Epoch 19/100   Target cls 1
# Pred logit: [0.39,0.61] Best proto: True  c: 1.0
# L_pred: 0.00  L_dist: 170.41  L_AE: 0.00  L_proto: 7659.81  Loss: 10761.50
# Grad abs/mean: 582.50/-12.43  Grad min/max: -1000.00/1000.00
#
# Epoch 20/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 102.52  L_AE: 0.00  L_proto: 24772.11  Loss: 7826.67
# Grad abs/mean: 495.46/150.86  Grad min/max: -574.12/1000.00
#
# Epoch 21/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 162.04  L_AE: 0.00  L_proto: 7606.62  Loss: 24872.92
# Grad abs/mean: 744.12/-39.98  Grad min/max: -1000.00/1000.00
#
# Epoch 22/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 0.99  L_dist: 138.50  L_AE: 0.00  L_proto: 30244.41  Loss: 7766.16
# Grad abs/mean: 603.71/154.53  Grad min/max: -658.09/1000.00
#
# Epoch 23/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 165.68  L_AE: 0.00  L_proto: 10971.23  Loss: 30380.54
# Grad abs/mean: 801.20/-62.86  Grad min/max: -1000.00/1000.00
#
# Epoch 24/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 126.27  L_AE: 0.00  L_proto: 13907.91  Loss: 11134.37
# Grad abs/mean: 731.38/237.90  Grad min/max: -1000.00/1000.00
#
# Epoch 25/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 167.93  L_AE: 0.00  L_proto: 10058.63  Loss: 14031.99
# Grad abs/mean: 667.21/-80.43  Grad min/max: -1000.00/1000.00
#
# Epoch 26/100   Target cls 1
# Pred logit: [0.64,0.36] Best proto: True  c: 1.0
# L_pred: 0.28  L_dist: 152.87  L_AE: 0.00  L_proto: 32860.77  Loss: 10223.82
# Grad abs/mean: 717.10/117.13  Grad min/max: -844.49/1000.00
#
# Epoch 27/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 151.77  L_AE: 0.00  L_proto: 9159.21  Loss: 33010.38
# Grad abs/mean: 779.40/-40.93  Grad min/max: -1000.00/1000.00
#
# Epoch 28/100   Target cls 1
# Pred logit: [0.47,0.53] Best proto: True  c: 1.0
# L_pred: 0.00  L_dist: 111.10  L_AE: 0.00  L_proto: 14240.22  Loss: 9308.63
# Grad abs/mean: 596.70/32.36  Grad min/max: -1000.00/848.94
#
# Epoch 29/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 175.86  L_AE: 0.00  L_proto: 8177.27  Loss: 14348.55
# Grad abs/mean: 850.10/-183.43  Grad min/max: -1000.00/1000.00
#
# Epoch 30/100   Target cls 1
# Pred logit: [0.07,0.93] Best proto: True  c: 1.0
# L_pred: 0.00  L_dist: 115.20  L_AE: 0.00  L_proto: 28767.77  Loss: 8350.29
# Grad abs/mean: 674.29/19.33  Grad min/max: -1000.00/1000.00
#
# Epoch 31/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 171.37  L_AE: 0.00  L_proto: 16638.03  Loss: 28880.10
# Grad abs/mean: 929.22/-40.33  Grad min/max: -1000.00/1000.00
#
# Epoch 32/100   Target cls 1
# Pred logit: [0.96,0.04] Best proto: True  c: 1.0
# L_pred: 0.92  L_dist: 150.14  L_AE: 0.00  L_proto: 6919.83  Loss: 16806.64
# Grad abs/mean: 760.34/315.89  Grad min/max: -1000.00/1000.00
#
# Epoch 33/100   Target cls 1
# Pred logit: [0.04,0.96] Best proto: True  c: 1.0
# L_pred: 0.00  L_dist: 162.84  L_AE: 0.00  L_proto: 47221.35  Loss: 7067.57
# Grad abs/mean: 498.87/-255.32  Grad min/max: -925.91/743.35
#
# Epoch 34/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 156.97  L_AE: 0.00  L_proto: 7668.38  Loss: 47380.55
# Grad abs/mean: 1000.00/333.33  Grad min/max: -1000.00/1000.00
#
# Epoch 35/100   Target cls 1
# Pred logit: [0.68,0.32] Best proto: True  c: 1.0
# L_pred: 0.36  L_dist: 122.65  L_AE: 0.00  L_proto: 24635.64  Loss: 7822.77
# Grad abs/mean: 504.23/-105.62  Grad min/max: -719.86/840.10
#
# Epoch 36/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 162.31  L_AE: 0.00  L_proto: 11160.29  Loss: 24755.47
# Grad abs/mean: 969.35/80.46  Grad min/max: -1000.00/1000.00
#
# Epoch 37/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 151.10  L_AE: 0.00  L_proto: 6565.30  Loss: 11319.96
# Grad abs/mean: 578.81/-64.39  Grad min/max: -1000.00/1000.00
#
# Epoch 38/100   Target cls 1
# Pred logit: [0.97,0.03] Best proto: True  c: 1.0
# L_pred: 0.94  L_dist: 73.82  L_AE: 0.00  L_proto: 18895.00  Loss: 6714.15
# Grad abs/mean: 459.97/166.99  Grad min/max: -790.23/1000.00
#
# Epoch 39/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 189.36  L_AE: 0.00  L_proto: 7376.24  Loss: 18967.37
# Grad abs/mean: 818.59/-374.14  Grad min/max: -1000.00/1000.00
#
# Epoch 40/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 160.20  L_AE: 0.00  L_proto: 4790.73  Loss: 7562.78
# Grad abs/mean: 547.22/115.03  Grad min/max: -1000.00/1000.00
#
# Epoch 41/100   Target cls 1
# Pred logit: [0.99,0.01] Best proto: True  c: 1.0
# L_pred: 0.98  L_dist: 164.55  L_AE: 0.00  L_proto: 6615.98  Loss: 4948.33
# Grad abs/mean: 387.73/-190.89  Grad min/max: -694.59/362.29
#
# Epoch 42/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 90.65  L_AE: 0.00  L_proto: 8150.37  Loss: 6777.81
# Grad abs/mean: 635.25/530.57  Grad min/max: -315.67/1000.00
#
# Epoch 43/100   Target cls 1
# Pred logit: [0.06,0.94] Best proto: True  c: 1.0
# L_pred: 0.00  L_dist: 129.00  L_AE: 0.00  L_proto: 30732.90  Loss: 8239.40
# Grad abs/mean: 457.15/-311.07  Grad min/max: -989.92/512.64
#
# Epoch 44/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 156.97  L_AE: 0.00  L_proto: 7668.38  Loss: 30858.78
# Grad abs/mean: 940.39/392.94  Grad min/max: -1000.00/1000.00
#
# Epoch 45/100   Target cls 1
# Pred logit: [0.00,1.00] Best proto: True  c: 1.0
# L_pred: 0.00  L_dist: 101.47  L_AE: 0.00  L_proto: 25300.21  Loss: 7822.77
# Grad abs/mean: 504.23/-105.62  Grad min/max: -719.86/840.10
#
# Epoch 46/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 176.42  L_AE: 0.00  L_proto: 6224.94  Loss: 25398.96
# Grad abs/mean: 912.83/-23.95  Grad min/max: -1000.00/1000.00
#
# Epoch 47/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 107.21  L_AE: 0.00  L_proto: 7314.77  Loss: 6398.53
# Grad abs/mean: 405.57/124.58  Grad min/max: -371.21/811.36
#
# Epoch 48/100   Target cls 1
# Pred logit: [0.96,0.04] Best proto: True  c: 1.0
# L_pred: 0.92  L_dist: 106.75  L_AE: 0.00  L_proto: 25483.60  Loss: 7420.19
# Grad abs/mean: 526.57/28.30  Grad min/max: -1000.00/724.82
#
# Epoch 49/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 162.05  L_AE: 0.00  L_proto: 10196.38  Loss: 25588.63
# Grad abs/mean: 888.07/-131.45  Grad min/max: -1000.00/1000.00
#
# Epoch 50/100   Target cls 1
# Pred logit: [0.99,0.01] Best proto: True  c: 1.0
# L_pred: 0.98  L_dist: 133.39  L_AE: 0.00  L_proto: 8744.67  Loss: 10355.88
# Grad abs/mean: 691.52/215.20  Grad min/max: -1000.00/1000.00
#
# Epoch 51/100   Target cls 1
# Pred logit: [0.00,1.00] Best proto: True  c: 1.0
# L_pred: 0.00  L_dist: 172.17  L_AE: 0.00  L_proto: 6724.82  Loss: 8875.75
# Grad abs/mean: 606.75/-33.05  Grad min/max: -1000.00/1000.00
#
# Epoch 52/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 102.20  L_AE: 0.00  L_proto: 9951.02  Loss: 6893.39
# Grad abs/mean: 540.14/10.60  Grad min/max: -1000.00/1000.00
#
# Epoch 53/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 164.83  L_AE: 0.00  L_proto: 6972.04  Loss: 10051.58
# Grad abs/mean: 586.53/-88.93  Grad min/max: -1000.00/1000.00
#
# Epoch 54/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 154.32  L_AE: 0.00  L_proto: 4335.45  Loss: 7134.34
# Grad abs/mean: 525.88/56.71  Grad min/max: -1000.00/1000.00
#
# Epoch 55/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 76.65  L_AE: 0.00  L_proto: 4843.03  Loss: 4487.37
# Grad abs/mean: 404.93/326.41  Grad min/max: -353.32/1000.00
#
# Epoch 56/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 44.20  L_AE: 0.00  L_proto: 10928.80  Loss: 4918.40
# Grad abs/mean: 246.70/-163.02  Grad min/max: -569.50/318.61
#
# Epoch 57/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 163.15  L_AE: 0.00  L_proto: 26213.06  Loss: 10972.22
# Grad abs/mean: 749.59/34.21  Grad min/max: -1000.00/1000.00
#
# Epoch 58/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 145.17  L_AE: 0.00  L_proto: 3977.07  Loss: 26373.59
# Grad abs/mean: 680.79/-129.16  Grad min/max: -1000.00/1000.00
#
# Epoch 59/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 161.88  L_AE: 0.00  L_proto: 4258.34  Loss: 4120.09
# Grad abs/mean: 286.36/-88.17  Grad min/max: -625.18/353.82
#
# Epoch 60/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 74.50  L_AE: 0.00  L_proto: 6625.12  Loss: 4417.61
# Grad abs/mean: 497.93/443.37  Grad min/max: -210.38/923.10
#
# Epoch 61/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 79.33  L_AE: 0.00  L_proto: 6007.38  Loss: 6698.36
# Grad abs/mean: 274.52/-173.17  Grad min/max: -684.32/291.01
#
# Epoch 62/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 113.37  L_AE: 0.00  L_proto: 6054.00  Loss: 6085.40
# Grad abs/mean: 240.54/-6.94  Grad min/max: -705.85/721.02
#
# Epoch 63/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 86.14  L_AE: 0.00  L_proto: 7431.99  Loss: 6165.58
# Grad abs/mean: 429.24/366.37  Grad min/max: -282.89/1000.00
#
# Epoch 64/100   Target cls 1
# Pred logit: [0.85,0.15] Best proto: True  c: 1.0
# L_pred: 0.71  L_dist: 36.46  L_AE: 0.00  L_proto: 6297.91  Loss: 7516.77
# Grad abs/mean: 277.33/-138.00  Grad min/max: -469.67/348.30
#
# Epoch 65/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 158.02  L_AE: 0.00  L_proto: 5822.79  Loss: 6333.44
# Grad abs/mean: 755.93/-375.57  Grad min/max: -1000.00/1000.00
#
# Epoch 66/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 82.14  L_AE: 0.00  L_proto: 6234.80  Loss: 5978.24
# Grad abs/mean: 375.16/316.37  Grad min/max: -264.54/1000.00
#
# Epoch 67/100   Target cls 1
# Pred logit: [0.00,1.00] Best proto: True  c: 1.0
# L_pred: 0.00  L_dist: 76.67  L_AE: 0.00  L_proto: 13912.71  Loss: 6315.79
# Grad abs/mean: 428.85/-287.27  Grad min/max: -1000.00/476.09
#
# Epoch 68/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 136.52  L_AE: 0.00  L_proto: 6148.46  Loss: 13987.22
# Grad abs/mean: 931.94/401.39  Grad min/max: -1000.00/1000.00
#
# Epoch 69/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 85.78  L_AE: 0.00  L_proto: 6026.81  Loss: 6282.84
# Grad abs/mean: 245.57/-60.69  Grad min/max: -465.60/493.17
#
# Epoch 70/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 97.55  L_AE: 0.00  L_proto: 6528.72  Loss: 6111.28
# Grad abs/mean: 188.40/11.95  Grad min/max: -264.70/395.52
#
# Epoch 71/100   Target cls 1
# Pred logit: [0.97,0.03] Best proto: True  c: 1.0
# L_pred: 0.93  L_dist: 79.72  L_AE: 0.00  L_proto: 6108.34  Loss: 6624.71
# Grad abs/mean: 409.06/-30.19  Grad min/max: -1000.00/698.57
#
# Epoch 72/100   Target cls 1
# Pred logit: [0.60,0.40] Best proto: True  c: 1.0
# L_pred: 0.21  L_dist: 69.83  L_AE: 0.00  L_proto: 4864.58  Loss: 6186.96
# Grad abs/mean: 224.28/48.53  Grad min/max: -520.77/341.62
#
# Epoch 73/100   Target cls 1
# Pred logit: [0.66,0.34] Best proto: True  c: 1.0
# L_pred: 0.33  L_dist: 57.49  L_AE: 0.00  L_proto: 5598.03  Loss: 4932.72
# Grad abs/mean: 105.99/85.07  Grad min/max: -94.12/318.93
#
# Epoch 74/100   Target cls 1
# Pred logit: [0.99,0.01] Best proto: True  c: 1.0
# L_pred: 0.98  L_dist: 111.45  L_AE: 0.00  L_proto: 49536.87  Loss: 5654.11
# Grad abs/mean: 490.65/-119.98  Grad min/max: -773.06/624.40
#
# Epoch 75/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 144.03  L_AE: 0.00  L_proto: 13464.44  Loss: 49646.40
# Grad abs/mean: 1000.00/111.11  Grad min/max: -1000.00/1000.00
#
# Epoch 76/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 153.93  L_AE: 0.00  L_proto: 5354.19  Loss: 13606.01
# Grad abs/mean: 637.98/-20.77  Grad min/max: -1000.00/1000.00
#
# Epoch 77/100   Target cls 1
# Pred logit: [0.83,0.17] Best proto: True  c: 1.0
# L_pred: 0.66  L_dist: 85.73  L_AE: 0.00  L_proto: 2882.49  Loss: 5505.64
# Grad abs/mean: 321.59/20.71  Grad min/max: -1000.00/503.93
#
# Epoch 78/100   Target cls 1
# Pred logit: [0.14,0.86] Best proto: True  c: 1.0
# L_pred: 0.00  L_dist: 93.35  L_AE: 0.00  L_proto: 5847.23  Loss: 2966.62
# Grad abs/mean: 374.97/-16.67  Grad min/max: -1000.00/840.17
#
# Epoch 79/100   Target cls 1
# Pred logit: [0.99,0.01] Best proto: True  c: 1.0
# L_pred: 0.99  L_dist: 105.58  L_AE: 0.00  L_proto: 9652.14  Loss: 5938.26
# Grad abs/mean: 597.32/-104.12  Grad min/max: -1000.00/1000.00
#
# Epoch 80/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 133.20  L_AE: 0.00  L_proto: 7398.41  Loss: 9755.99
# Grad abs/mean: 879.52/205.87  Grad min/max: -1000.00/1000.00
#
# Epoch 81/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 95.74  L_AE: 0.00  L_proto: 6258.73  Loss: 7529.44
# Grad abs/mean: 234.92/-189.31  Grad min/max: -490.35/190.76
#
# Epoch 82/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 119.93  L_AE: 0.00  L_proto: 16379.05  Loss: 6353.06
# Grad abs/mean: 373.62/82.08  Grad min/max: -515.90/1000.00
#
# Epoch 83/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 0.99  L_dist: 87.54  L_AE: 0.00  L_proto: 5802.27  Loss: 16497.04
# Grad abs/mean: 734.43/-151.80  Grad min/max: -1000.00/1000.00
#
# Epoch 84/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 65.16  L_AE: 0.00  L_proto: 4319.72  Loss: 5888.30
# Grad abs/mean: 374.03/79.06  Grad min/max: -708.55/1000.00
#
# Epoch 85/100   Target cls 1
# Pred logit: [0.99,0.01] Best proto: True  c: 1.0
# L_pred: 0.98  L_dist: 113.52  L_AE: 0.00  L_proto: 2447.34  Loss: 4384.14
# Grad abs/mean: 365.55/-237.71  Grad min/max: -748.77/560.53
#
# Epoch 86/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 58.44  L_AE: 0.00  L_proto: 5651.88  Loss: 2559.21
# Grad abs/mean: 433.65/294.13  Grad min/max: -408.77/1000.00
#
# Epoch 87/100   Target cls 1
# Pred logit: [0.11,0.89] Best proto: True  c: 1.0
# L_pred: 0.00  L_dist: 106.89  L_AE: 0.00  L_proto: 21871.69  Loss: 5709.57
# Grad abs/mean: 462.50/-200.16  Grad min/max: -1000.00/541.94
#
# Epoch 88/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 99.98  L_AE: 0.00  L_proto: 4663.19  Loss: 21975.82
# Grad abs/mean: 929.92/-263.25  Grad min/max: -1000.00/1000.00
#
# Epoch 89/100   Target cls 1
# Pred logit: [0.99,0.01] Best proto: True  c: 1.0
# L_pred: 0.97  L_dist: 137.96  L_AE: 0.00  L_proto: 7680.23  Loss: 4761.64
# Grad abs/mean: 393.45/-94.16  Grad min/max: -756.17/492.81
#
# Epoch 90/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 72.99  L_AE: 0.00  L_proto: 8906.09  Loss: 7815.93
# Grad abs/mean: 566.67/308.29  Grad min/max: -803.55/1000.00
#
# Epoch 91/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 94.70  L_AE: 0.00  L_proto: 9095.54  Loss: 8978.01
# Grad abs/mean: 276.55/-136.67  Grad min/max: -461.60/403.45
#
# Epoch 92/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 81.29  L_AE: 0.00  L_proto: 3862.09  Loss: 9188.75
# Grad abs/mean: 392.58/-283.51  Grad min/max: -730.90/251.76
#
# Epoch 93/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 60.43  L_AE: 0.00  L_proto: 6897.53  Loss: 3941.99
# Grad abs/mean: 307.46/-230.87  Grad min/max: -766.86/183.59
#
# Epoch 94/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 47.51  L_AE: 0.00  L_proto: 3344.81  Loss: 6957.04
# Grad abs/mean: 537.63/-42.26  Grad min/max: -1000.00/1000.00
#
# Epoch 95/100   Target cls 1
# Pred logit: [0.67,0.33] Best proto: True  c: 1.0
# L_pred: 0.34  L_dist: 48.88  L_AE: 0.00  L_proto: 1815.23  Loss: 3391.64
# Grad abs/mean: 237.90/-57.77  Grad min/max: -743.15/443.09
#
# Epoch 96/100   Target cls 1
# Pred logit: [0.99,0.01] Best proto: True  c: 1.0
# L_pred: 0.97  L_dist: 56.30  L_AE: 0.00  L_proto: 2748.21  Loss: 1862.83
# Grad abs/mean: 162.93/-73.77  Grad min/max: -562.42/144.38
#
# Epoch 97/100   Target cls 1
# Pred logit: [0.15,0.85] Best proto: True  c: 1.0
# L_pred: 0.00  L_dist: 59.21  L_AE: 0.00  L_proto: 1063.91  Loss: 2803.83
# Grad abs/mean: 364.17/67.73  Grad min/max: -704.81/762.45
#
# Epoch 98/100   Target cls 1
# Pred logit: [0.27,0.73] Best proto: True  c: 1.0
# L_pred: 0.00  L_dist: 62.04  L_AE: 0.00  L_proto: 2145.05  Loss: 1121.30
# Grad abs/mean: 175.18/8.26  Grad min/max: -540.14/356.11
#
# Epoch 99/100   Target cls 1
# Pred logit: [0.66,0.34] Best proto: True  c: 1.0
# L_pred: 0.32  L_dist: 44.02  L_AE: 0.00  L_proto: 1588.95  Loss: 2205.23
# Grad abs/mean: 525.68/300.23  Grad min/max: -690.75/1000.00
#
# Epoch 0/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: False  c: 1.0
# L_pred: 1.00  L_dist: 145.98  L_AE: 0.00  L_proto: 14146.54  Loss: 1827.85
# Grad abs/mean: 427.05/-73.48  Grad min/max: -644.74/919.63
#
# Epoch 1/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: False  c: 1.0
# L_pred: 1.00  L_dist: 85.43  L_AE: 0.00  L_proto: 12818.92  Loss: 14290.36
# Grad abs/mean: 676.09/36.92  Grad min/max: -1000.00/1000.00
#
# Epoch 2/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: False  c: 1.0
# L_pred: 1.00  L_dist: 200.38  L_AE: 0.00  L_proto: 7136.45  Loss: 12902.86
# Grad abs/mean: 684.35/-164.84  Grad min/max: -1000.00/1000.00
#
# Epoch 3/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: False  c: 1.0
# L_pred: 1.00  L_dist: 93.90  L_AE: 0.00  L_proto: 26602.59  Loss: 7333.93
# Grad abs/mean: 601.81/131.17  Grad min/max: -756.82/1000.00
#
# Epoch 4/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: False  c: 1.0
# L_pred: 1.00  L_dist: 200.27  L_AE: 0.00  L_proto: 6914.28  Loss: 26694.85
# Grad abs/mean: 711.15/-84.54  Grad min/max: -1000.00/1000.00
#
# Epoch 5/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: False  c: 1.0
# L_pred: 1.00  L_dist: 89.71  L_AE: 0.00  L_proto: 24331.06  Loss: 7111.65
# Grad abs/mean: 588.48/126.36  Grad min/max: -737.07/1000.00
#
# Epoch 6/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: False  c: 1.0
# L_pred: 1.00  L_dist: 200.64  L_AE: 0.00  L_proto: 7182.85  Loss: 24419.21
# Grad abs/mean: 735.14/-59.91  Grad min/max: -1000.00/1000.00
#
# Epoch 7/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: False  c: 1.0
# L_pred: 1.00  L_dist: 82.81  L_AE: 0.00  L_proto: 26667.80  Loss: 7380.56
# Grad abs/mean: 549.86/179.17  Grad min/max: -581.36/1000.00
#
# Epoch 8/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: False  c: 1.0
# L_pred: 1.00  L_dist: 176.59  L_AE: 0.00  L_proto: 9078.55  Loss: 26749.18
# Grad abs/mean: 765.10/-106.40  Grad min/max: -1000.00/1000.00
#
# Epoch 9/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: False  c: 1.0
# L_pred: 1.00  L_dist: 97.57  L_AE: 0.00  L_proto: 25835.43  Loss: 9252.60
# Grad abs/mean: 682.38/168.37  Grad min/max: -639.73/1000.00
#
# Epoch 10/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: False  c: 1.0
# L_pred: 1.00  L_dist: 200.15  L_AE: 0.00  L_proto: 6959.19  Loss: 25931.27
# Grad abs/mean: 725.67/-136.08  Grad min/max: -1000.00/1000.00
#
# Epoch 11/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: False  c: 1.0
# L_pred: 1.00  L_dist: 86.55  L_AE: 0.00  L_proto: 24115.98  Loss: 7156.47
# Grad abs/mean: 591.85/125.84  Grad min/max: -734.95/1000.00
#
# Epoch 12/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: False  c: 1.0
# L_pred: 1.00  L_dist: 207.23  L_AE: 0.00  L_proto: 8016.20  Loss: 24201.13
# Grad abs/mean: 735.18/-67.04  Grad min/max: -1000.00/1000.00
#
# Epoch 13/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: False  c: 1.0
# L_pred: 1.00  L_dist: 102.69  L_AE: 0.00  L_proto: 28559.77  Loss: 8220.31
# Grad abs/mean: 597.51/140.20  Grad min/max: -704.53/1000.00
#
# Epoch 14/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: False  c: 1.0
# L_pred: 1.00  L_dist: 195.38  L_AE: 0.00  L_proto: 16638.03  Loss: 28660.63
# Grad abs/mean: 811.60/-44.92  Grad min/max: -1000.00/1000.00
#
# Epoch 15/100   Target cls 1
# Pred logit: [0.97,0.03] Best proto: False  c: 1.0
# L_pred: 0.93  L_dist: 153.53  L_AE: 0.00  L_proto: 7513.07  Loss: 16830.42
# Grad abs/mean: 760.23/315.79  Grad min/max: -1000.00/1000.00
#
# Epoch 16/100   Target cls 1
# Pred logit: [0.00,1.00] Best proto: True  c: 1.0
# L_pred: 0.00  L_dist: 152.98  L_AE: 0.00  L_proto: 40869.42  Loss: 7664.14
# Grad abs/mean: 457.62/-225.90  Grad min/max: -915.05/686.20
#
# Epoch 17/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 166.06  L_AE: 0.00  L_proto: 7668.38  Loss: 41018.93
# Grad abs/mean: 1000.00/333.33  Grad min/max: -1000.00/1000.00
#
# Epoch 18/100   Target cls 1
# Pred logit: [0.66,0.34] Best proto: True  c: 1.0
# L_pred: 0.33  L_dist: 148.95  L_AE: 0.00  L_proto: 25299.65  Loss: 7831.81
# Grad abs/mean: 503.62/-105.82  Grad min/max: -719.86/840.10
#
# Epoch 19/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 171.41  L_AE: 0.00  L_proto: 11160.29  Loss: 25445.51
# Grad abs/mean: 973.79/84.90  Grad min/max: -1000.00/1000.00
#
# Epoch 20/100   Target cls 1
# Pred logit: [0.99,0.01] Best proto: True  c: 1.0
# L_pred: 0.98  L_dist: 153.11  L_AE: 0.00  L_proto: 6936.81  Loss: 11329.00
# Grad abs/mean: 578.04/-64.41  Grad min/max: -1000.00/1000.00
#
# Epoch 21/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 126.65  L_AE: 0.00  L_proto: 17798.86  Loss: 7087.76
# Grad abs/mean: 508.43/63.28  Grad min/max: -1000.00/1000.00
#
# Epoch 22/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 175.05  L_AE: 0.00  L_proto: 9928.25  Loss: 17923.41
# Grad abs/mean: 786.61/-67.89  Grad min/max: -1000.00/1000.00
#
# Epoch 23/100   Target cls 1
# Pred logit: [0.01,0.99] Best proto: True  c: 1.0
# L_pred: 0.00  L_dist: 135.58  L_AE: 0.00  L_proto: 18828.27  Loss: 10100.70
# Grad abs/mean: 725.86/-271.50  Grad min/max: -1000.00/999.44
#
# Epoch 24/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 197.41  L_AE: 0.00  L_proto: 14981.44  Loss: 18960.71
# Grad abs/mean: 808.96/79.93  Grad min/max: -1000.00/1000.00
#
# Epoch 25/100   Target cls 1
# Pred logit: [0.01,0.99] Best proto: True  c: 1.0
# L_pred: 0.00  L_dist: 133.33  L_AE: 0.00  L_proto: 22933.58  Loss: 15175.82
# Grad abs/mean: 573.44/-257.28  Grad min/max: -1000.00/1000.00
#
# Epoch 26/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 156.70  L_AE: 0.00  L_proto: 6769.11  Loss: 23063.85
# Grad abs/mean: 762.56/257.66  Grad min/max: -943.04/1000.00
#
# Epoch 27/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 93.12  L_AE: 0.00  L_proto: 38186.83  Loss: 6923.42
# Grad abs/mean: 441.62/5.23  Grad min/max: -779.86/1000.00
#
# Epoch 28/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 185.51  L_AE: 0.00  L_proto: 6224.94  Loss: 38278.45
# Grad abs/mean: 1000.00/-111.11  Grad min/max: -1000.00/1000.00
#
# Epoch 29/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 151.56  L_AE: 0.00  L_proto: 10530.07  Loss: 6407.58
# Grad abs/mean: 404.55/124.39  Grad min/max: -368.01/811.36
#
# Epoch 30/100   Target cls 1
# Pred logit: [0.92,0.08] Best proto: True  c: 1.0
# L_pred: 0.83  L_dist: 149.29  L_AE: 0.00  L_proto: 6793.16  Loss: 10679.42
# Grad abs/mean: 661.08/216.63  Grad min/max: -1000.00/1000.00
#
# Epoch 31/100   Target cls 1
# Pred logit: [0.00,1.00] Best proto: True  c: 1.0
# L_pred: 0.00  L_dist: 108.31  L_AE: 0.00  L_proto: 25053.63  Loss: 6939.92
# Grad abs/mean: 265.50/10.34  Grad min/max: -389.53/677.20
#
# Epoch 32/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 180.22  L_AE: 0.00  L_proto: 13370.11  Loss: 25159.22
# Grad abs/mean: 846.69/-19.06  Grad min/max: -1000.00/1000.00
#
# Epoch 33/100   Target cls 1
# Pred logit: [0.01,0.99] Best proto: True  c: 1.0
# L_pred: 0.00  L_dist: 150.92  L_AE: 0.00  L_proto: 8406.55  Loss: 13547.53
# Grad abs/mean: 733.59/253.02  Grad min/max: -1000.00/1000.00
#
# Epoch 34/100   Target cls 1
# Pred logit: [0.20,0.80] Best proto: True  c: 1.0
# L_pred: 0.00  L_dist: 114.13  L_AE: 0.00  L_proto: 8936.02  Loss: 8554.23
# Grad abs/mean: 433.56/-53.04  Grad min/max: -843.65/663.02
#
# Epoch 35/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 185.51  L_AE: 0.00  L_proto: 6224.94  Loss: 9047.38
# Grad abs/mean: 929.74/-70.80  Grad min/max: -1000.00/1000.00
#
# Epoch 36/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 130.88  L_AE: 0.00  L_proto: 8505.50  Loss: 6407.58
# Grad abs/mean: 404.55/124.39  Grad min/max: -368.01/811.36
#
# Epoch 37/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 126.43  L_AE: 0.00  L_proto: 8557.35  Loss: 8634.64
# Grad abs/mean: 584.86/140.41  Grad min/max: -1000.00/841.00
#
# Epoch 38/100   Target cls 1
# Pred logit: [0.00,1.00] Best proto: True  c: 1.0
# L_pred: 0.00  L_dist: 159.16  L_AE: 0.00  L_proto: 6534.38  Loss: 8681.79
# Grad abs/mean: 355.21/48.48  Grad min/max: -598.15/666.39
#
# Epoch 39/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 139.94  L_AE: 0.00  L_proto: 5128.39  Loss: 6690.08
# Grad abs/mean: 482.28/-53.34  Grad min/max: -1000.00/869.77
#
# Epoch 40/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 194.14  L_AE: 0.00  L_proto: 6684.32  Loss: 5266.02
# Grad abs/mean: 637.71/34.55  Grad min/max: -924.01/1000.00
#
# Epoch 41/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 89.49  L_AE: 0.00  L_proto: 19239.46  Loss: 6875.48
# Grad abs/mean: 471.09/82.00  Grad min/max: -642.04/838.78
#
# Epoch 42/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 138.97  L_AE: 0.00  L_proto: 49345.36  Loss: 19327.48
# Grad abs/mean: 684.78/20.72  Grad min/max: -1000.00/1000.00
#
# Epoch 43/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 185.51  L_AE: 0.00  L_proto: 6224.94  Loss: 49482.04
# Grad abs/mean: 815.21/-11.42  Grad min/max: -1000.00/1000.00
#
# Epoch 44/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 148.92  L_AE: 0.00  L_proto: 7294.15  Loss: 6407.58
# Grad abs/mean: 404.55/124.39  Grad min/max: -368.01/811.36
#
# Epoch 45/100   Target cls 1
# Pred logit: [0.00,1.00] Best proto: True  c: 1.0
# L_pred: 0.00  L_dist: 97.70  L_AE: 0.00  L_proto: 33358.64  Loss: 7441.06
# Grad abs/mean: 587.52/-6.86  Grad min/max: -861.21/852.90
#
# Epoch 46/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 169.92  L_AE: 0.00  L_proto: 9099.13  Loss: 33453.65
# Grad abs/mean: 857.65/-121.37  Grad min/max: -1000.00/1000.00
#
# Epoch 47/100   Target cls 1
# Pred logit: [0.01,0.99] Best proto: True  c: 1.0
# L_pred: 0.00  L_dist: 113.78  L_AE: 0.00  L_proto: 23417.27  Loss: 9266.56
# Grad abs/mean: 739.54/47.04  Grad min/max: -1000.00/1000.00
#
# Epoch 48/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 172.11  L_AE: 0.00  L_proto: 27648.34  Loss: 23528.24
# Grad abs/mean: 727.77/-61.10  Grad min/max: -1000.00/1000.00
#
# Epoch 49/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 128.18  L_AE: 0.00  L_proto: 8670.52  Loss: 27817.96
# Grad abs/mean: 834.84/-103.31  Grad min/max: -1000.00/1000.00
#
# Epoch 50/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 154.05  L_AE: 0.00  L_proto: 4424.51  Loss: 8796.63
# Grad abs/mean: 548.38/-48.62  Grad min/max: -1000.00/1000.00
#
# Epoch 51/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 33.26  L_AE: 0.00  L_proto: 12682.22  Loss: 4576.36
# Grad abs/mean: 326.06/-30.10  Grad min/max: -983.60/461.15
#
# Epoch 52/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 210.17  L_AE: 0.00  L_proto: 19292.85  Loss: 12714.97
# Grad abs/mean: 820.05/-375.60  Grad min/max: -1000.00/1000.00
#
# Epoch 53/100   Target cls 1
# Pred logit: [0.99,0.01] Best proto: True  c: 1.0
# L_pred: 0.99  L_dist: 116.67  L_AE: 0.00  L_proto: 12407.71  Loss: 19499.87
# Grad abs/mean: 787.24/-63.88  Grad min/max: -1000.00/1000.00
#
# Epoch 54/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# L_pred: 1.00  L_dist: 193.57  L_AE: 0.00  L_proto: 5939.60  Loss: 12522.36
# Grad abs/mean: 643.83/-75.22  Grad min/max: -1000.00/1000.00
#
# Epoch 55/100   Target cls 1
# Pred logit: [0.59,0.41] Best proto: True  c: 1.0
# L_pred: 0.17  L_dist: 61.63  L_AE: 0.00  L_proto: 8877.51  Loss: 6130.32
# Grad abs/mean: 388.20/82.14  Grad min/max: -503.57/718.61
#
# Epoch 56/100   Target cls 1
# Pred logit: [1.00,0.00] Best proto: True  c: 1.0
# ...
# Best prob. 0.76 Best val. 0.46 Best dist. 1.18 Best context 0.39
#
# i_sample/N_samples: 9/10
# #epoch 265/300.
# self.alpha: 0.6. self.gamma: 0.1
# Valid True. Best True.
# Pred logits: [0.87,0.13] Target prob [0.5] Target cls 0
# Pred context: [0.44,0.99] Target ctx [[1. 1.]]
# Raw Dist loss 1.19 Val loss 0.33  Context loss 0.42
# Scaled Dist loss 0.12 Val loss 0.20  Context loss 0.17; Loss total 0.45
# Grad mean/abs -0.04/0.06  Grad min/max -0.13/0.04
# Best prob. 0.76 Best val. 0.46 Best dist. 1.18 Best context 0.39
#
# i_sample/N_samples: 9/10
# #epoch 266/300.
# self.alpha: 0.6. self.gamma: 0.1
# Valid True. Best True.
# Pred logits: [0.87,0.13] Target prob [0.5] Target cls 0
# Pred context: [0.43,0.99] Target ctx [[1. 1.]]
# Raw Dist loss 1.20 Val loss 0.33  Context loss 0.42
# Scaled Dist loss 0.12 Val loss 0.20  Context loss 0.17; Loss total 0.45
# Grad mean/abs 0.02/0.07  Grad min/max -0.08/0.11
# Best prob. 0.76 Best val. 0.46 Best dist. 1.18 Best context 0.39
#
# i_sample/N_samples: 9/10
# #epoch 267/300.
# self.alpha: 0.6. self.gamma: 0.1
# Valid True. Best True.
# Pred logits: [0.87,0.13] Target prob [0.5] Target cls 0
# Pred context: [0.44,0.99] Target ctx [[1. 1.]]
# Raw Dist loss 1.18 Val loss 0.34  Context loss 0.42
# Scaled Dist loss 0.12 Val loss 0.20  Context loss 0.17; Loss total 0.45
# Grad mean/abs -0.04/0.11  Grad min/max -0.14/0.15
# Best prob. 0.76 Best val. 0.46 Best dist. 1.18 Best context 0.39
#
# i_sample/N_samples: 9/10
# #epoch 268/300.
# self.alpha: 0.6. self.gamma: 0.1
# Valid True. Best True.
# Pred logits: [0.87,0.13] Target prob [0.5] Target cls 0
# Pred context: [0.44,0.99] Target ctx [[1. 1.]]
# Raw Dist loss 1.19 Val loss 0.33  Context loss 0.42
# Scaled Dist loss 0.12 Val loss 0.20  Context loss 0.17; Loss total 0.45
# Grad mean/abs 0.07/0.11  Grad min/max -0.08/0.17
# Best prob. 0.76 Best val. 0.46 Best dist. 1.18 Best context 0.39
#
# i_sample/N_samples: 9/10
# #epoch 269/300.
# self.alpha: 0.6. self.gamma: 0.1
# Valid True. Best True.
# Pred logits: [0.87,0.13] Target prob [0.5] Target cls 0
# Pred context: [0.44,0.99] Target ctx [[1. 1.]]
# Raw Dist loss 1.19 Val loss 0.33  Context loss 0.42
# Scaled Dist loss 0.12 Val loss 0.20  Context loss 0.17; Loss total 0.45
# Grad mean/abs -0.04/0.07  Grad min/max -0.13/0.04
# Best prob. 0.76 Best val. 0.46 Best dist. 1.18 Best context 0.39
#
# i_sample/N_samples: 9/10
# #epoch 270/300.
# self.alpha: 0.6. self.gamma: 0.1
# Valid True. Best True.
# Pred logits: [0.87,0.13] Target prob [0.5] Target cls 0
# Pred context: [0.43,0.99] Target ctx [[1. 1.]]
# Raw Dist loss 1.19 Val loss 0.33  Context loss 0.42
# Scaled Dist loss 0.12 Val loss 0.20  Context loss 0.17; Loss total 0.45
# Grad mean/abs 0.02/0.07  Grad min/max -0.08/0.11
# Best prob. 0.76 Best val. 0.46 Best dist. 1.18 Best context 0.39
#
# i_sample/N_samples: 9/10
# #epoch 271/300.
# self.alpha: 0.6. self.gamma: 0.1
# Valid True. Best True.
# Pred logits: [0.87,0.13] Target prob [0.5] Target cls 0
# Pred context: [0.44,0.99] Target ctx [[1. 1.]]
# Raw Dist loss 1.19 Val loss 0.33  Context loss 0.42
# Scaled Dist loss 0.12 Val loss 0.20  Context loss 0.17; Loss total 0.45
# Grad mean/abs -0.04/0.07  Grad min/max -0.13/0.05
# Best prob. 0.76 Best val. 0.46 Best dist. 1.18 Best context 0.39
#
# i_sample/N_samples: 9/10
# #epoch 272/300.
# self.alpha: 0.6. self.gamma: 0.1
# Valid True. Best True.
# Pred logits: [0.87,0.13] Target prob [0.5] Target cls 0
# Pred context: [0.43,0.99] Target ctx [[1. 1.]]
# Raw Dist loss 1.20 Val loss 0.33  Context loss 0.42
# Scaled Dist loss 0.12 Val loss 0.20  Context loss 0.17; Loss total 0.45
# Grad mean/abs 0.02/0.07  Grad min/max -0.08/0.11
# Best prob. 0.76 Best val. 0.46 Best dist. 1.18 Best context 0.39
#
# i_sample/N_samples: 9/10
# #epoch 273/300.
# self.alpha: 0.6. self.gamma: 0.1
# Valid True. Best True.
# Pred logits: [0.87,0.13] Target prob [0.5] Target cls 0
# Pred context: [0.44,0.99] Target ctx [[1. 1.]]
# Raw Dist loss 1.18 Val loss 0.33  Context loss 0.42
# Scaled Dist loss 0.12 Val loss 0.20  Context loss 0.17; Loss total 0.45
# Grad mean/abs -0.04/0.11  Grad min/max -0.14/0.15
# Best prob. 0.76 Best val. 0.46 Best dist. 1.18 Best context 0.39
#
# i_sample/N_samples: 9/10
# #epoch 274/300.
# self.alpha: 0.6. self.gamma: 0.1
# Valid True. Best True.
# Pred logits: [0.87,0.13] Target prob [0.5] Target cls 0
# Pred context: [0.43,0.99] Target ctx [[1. 1.]]
# Raw Dist loss 1.19 Val loss 0.33  Context loss 0.42
# Scaled Dist loss 0.12 Val loss 0.20  Context loss 0.17; Loss total 0.45
# Grad mean/abs 0.07/0.11  Grad min/max -0.08/0.17
# Best prob. 0.76 Best val. 0.46 Best dist. 1.18 Best context 0.39
#
# i_sample/N_samples: 9/10
# #epoch 275/300.
# self.alpha: 0.6. self.gamma: 0.1
# Valid True. Best True.
# Pred logits: [0.87,0.13] Target prob [0.5] Target cls 0
# Pred context: [0.44,0.99] Target ctx [[1. 1.]]
# Raw Dist loss 1.19 Val loss 0.33  Context loss 0.42
# Scaled Dist loss 0.12 Val loss 0.20  Context loss 0.17; Loss total 0.45
# Grad mean/abs -0.04/0.07  Grad min/max -0.13/0.05
# Best prob. 0.76 Best val. 0.46 Best dist. 1.18 Best context 0.39
#
# i_sample/N_samples: 9/10
# #epoch 276/300.
# self.alpha: 0.6. self.gamma: 0.1
# Valid True. Best True.
# Pred logits: [0.87,0.13] Target prob [0.5] Target cls 0
# Pred context: [0.43,0.99] Target ctx [[1. 1.]]
# Raw Dist loss 1.20 Val loss 0.33  Context loss 0.42
# Scaled Dist loss 0.12 Val loss 0.20  Context loss 0.17; Loss total 0.45
# Grad mean/abs 0.05/0.09  Grad min/max -0.07/0.14
# Best prob. 0.76 Best val. 0.46 Best dist. 1.18 Best context 0.39
#
# i_sample/N_samples: 9/10
# #epoch 277/300.
# self.alpha: 0.6. self.gamma: 0.1
# Valid True. Best True.
# Pred logits: [0.87,0.13] Target prob [0.5] Target cls 0
# Pred context: [0.44,0.99] Target ctx [[1. 1.]]
# Raw Dist loss 1.19 Val loss 0.33  Context loss 0.42
# Scaled Dist loss 0.12 Val loss 0.20  Context loss 0.17; Loss total 0.45
# Grad mean/abs -0.04/0.11  Grad min/max -0.14/0.15
# Best prob. 0.76 Best val. 0.46 Best dist. 1.18 Best context 0.39
#
# i_sample/N_samples: 9/10
# #epoch 278/300.
# self.alpha: 0.6. self.gamma: 0.1
# Valid True. Best True.
# Pred logits: [0.87,0.13] Target prob [0.5] Target cls 0
# Pred context: [0.43,0.99] Target ctx [[1. 1.]]
# Raw Dist loss 1.19 Val loss 0.33  Context loss 0.42
# Scaled Dist loss 0.12 Val loss 0.20  Context loss 0.17; Loss total 0.45
# Grad mean/abs 0.02/0.07  Grad min/max -0.08/0.11
# Best prob. 0.76 Best val. 0.46 Best dist. 1.18 Best context 0.39
#
# i_sample/N_samples: 9/10
# #epoch 279/300.
# self.alpha: 0.6. self.gamma: 0.1
# Valid True. Best True.
# Pred logits: [0.87,0.13] Target prob [0.5] Target cls 0
# Pred context: [0.44,0.99] Target ctx [[1. 1.]]
# Raw Dist loss 1.19 Val loss 0.33  Context loss 0.42
# Scaled Dist loss 0.12 Val loss 0.20  Context loss 0.17; Loss total 0.45
# Grad mean/abs -0.04/0.07  Grad min/max -0.13/0.04
# Best prob. 0.76 Best val. 0.46 Best dist. 1.18 Best context 0.39
#
# i_sample/N_samples: 9/10
# #epoch 280/300.
# self.alpha: 0.6. self.gamma: 0.1
# Valid True. Best True.
# Pred logits: [0.87,0.13] Target prob [0.5] Target cls 0
# Pred context: [0.43,0.99] Target ctx [[1. 1.]]
# Raw Dist loss 1.20 Val loss 0.33  Context loss 0.42
# Scaled Dist loss 0.12 Val loss 0.20  Context loss 0.17; Loss total 0.45
# Grad mean/abs 0.05/0.09  Grad min/max -0.07/0.14
# Best prob. 0.76 Best val. 0.46 Best dist. 1.18 Best context 0.39
#
# i_sample/N_samples: 9/10
# #epoch 281/300.
# self.alpha: 0.6. self.gamma: 0.1
# Valid True. Best True.
# Pred logits: [0.87,0.13] Target prob [0.5] Target cls 0
# Pred context: [0.44,0.99] Target ctx [[1. 1.]]
# Raw Dist loss 1.19 Val loss 0.33  Context loss 0.42
# Scaled Dist loss 0.12 Val loss 0.20  Context loss 0.17; Loss total 0.45
# Grad mean/abs -0.04/0.11  Grad min/max -0.14/0.15
# Best prob. 0.76 Best val. 0.46 Best dist. 1.18 Best context 0.39
#
# i_sample/N_samples: 9/10
# #epoch 282/300.
# self.alpha: 0.6. self.gamma: 0.1
# Valid True. Best True.
# Pred logits: [0.87,0.13] Target prob [0.5] Target cls 0
# Pred context: [0.44,0.99] Target ctx [[1. 1.]]
# Raw Dist loss 1.19 Val loss 0.33  Context loss 0.42
# Scaled Dist loss 0.12 Val loss 0.20  Context loss 0.17; Loss total 0.45
# Grad mean/abs 0.02/0.07  Grad min/max -0.08/0.11
# Best prob. 0.76 Best val. 0.46 Best dist. 1.18 Best context 0.39
#
# i_sample/N_samples: 9/10
# #epoch 283/300.
# self.alpha: 0.6. self.gamma: 0.1
# Valid True. Best True.
# Pred logits: [0.87,0.13] Target prob [0.5] Target cls 0
# Pred context: [0.44,0.99] Target ctx [[1. 1.]]
# Raw Dist loss 1.19 Val loss 0.33  Context loss 0.42
# Scaled Dist loss 0.12 Val loss 0.20  Context loss 0.17; Loss total 0.45
# Grad mean/abs -0.04/0.07  Grad min/max -0.13/0.04
# Best prob. 0.76 Best val. 0.46 Best dist. 1.18 Best context 0.39
#
# i_sample/N_samples: 9/10
# #epoch 284/300.
# self.alpha: 0.6. self.gamma: 0.1
# Valid True. Best True.
# Pred logits: [0.87,0.13] Target prob [0.5] Target cls 0
# Pred context: [0.43,0.99] Target ctx [[1. 1.]]
# Raw Dist loss 1.20 Val loss 0.33  Context loss 0.42
# Scaled Dist loss 0.12 Val loss 0.20  Context loss 0.17; Loss total 0.45
# Grad mean/abs 0.05/0.09  Grad min/max -0.07/0.14
# Best prob. 0.76 Best val. 0.46 Best dist. 1.18 Best context 0.39
#
# i_sample/N_samples: 9/10
# #epoch 285/300.
# self.alpha: 0.6. self.gamma: 0.1
# Valid True. Best True.
# Pred logits: [0.87,0.13] Target prob [0.5] Target cls 0
# Pred context: [0.44,0.99] Target ctx [[1. 1.]]
# Raw Dist loss 1.19 Val loss 0.33  Context loss 0.42
# Scaled Dist loss 0.12 Val loss 0.20  Context loss 0.17; Loss total 0.45
# Grad mean/abs -0.04/0.07  Grad min/max -0.13/0.04
# Best prob. 0.76 Best val. 0.46 Best dist. 1.18 Best context 0.39
#
# i_sample/N_samples: 9/10
# #epoch 286/300.
# self.alpha: 0.6. self.gamma: 0.1
# Valid True. Best True.
# Pred logits: [0.87,0.13] Target prob [0.5] Target cls 0
# Pred context: [0.44,0.99] Target ctx [[1. 1.]]
# Raw Dist loss 1.19 Val loss 0.33  Context loss 0.42
# Scaled Dist loss 0.12 Val loss 0.20  Context loss 0.17; Loss total 0.45
# Grad mean/abs -0.00/0.02  Grad min/max -0.03/0.04
# Best prob. 0.76 Best val. 0.46 Best dist. 1.18 Best context 0.39
#
# i_sample/N_samples: 9/10
# #epoch 287/300.
# self.alpha: 0.6. self.gamma: 0.1
# Valid True. Best True.
# Pred logits: [0.87,0.13] Target prob [0.5] Target cls 0
# Pred context: [0.44,0.99] Target ctx [[1. 1.]]
# Raw Dist loss 1.19 Val loss 0.33  Context loss 0.42
# Scaled Dist loss 0.12 Val loss 0.20  Context loss 0.17; Loss total 0.45
# Grad mean/abs -0.01/0.07  Grad min/max -0.14/0.06
# Best prob. 0.76 Best val. 0.46 Best dist. 1.18 Best context 0.39
#
# i_sample/N_samples: 9/10
# #epoch 288/300.
# self.alpha: 0.6. self.gamma: 0.1
# Valid True. Best True.
# Pred logits: [0.87,0.13] Target prob [0.5] Target cls 0
# Pred context: [0.43,0.99] Target ctx [[1. 1.]]
# Raw Dist loss 1.20 Val loss 0.33  Context loss 0.42
# Scaled Dist loss 0.12 Val loss 0.20  Context loss 0.17; Loss total 0.45
# Grad mean/abs 0.05/0.09  Grad min/max -0.07/0.14
# Best prob. 0.76 Best val. 0.46 Best dist. 1.18 Best context 0.39
#
# i_sample/N_samples: 9/10
# #epoch 289/300.
# self.alpha: 0.6. self.gamma: 0.1
# Valid True. Best True.
# Pred logits: [0.87,0.13] Target prob [0.5] Target cls 0
# Pred context: [0.44,0.99] Target ctx [[1. 1.]]
# Raw Dist loss 1.19 Val loss 0.33  Context loss 0.42
# Scaled Dist loss 0.12 Val loss 0.20  Context loss 0.17; Loss total 0.46
# Grad mean/abs -0.04/0.11  Grad min/max -0.14/0.15
# Best prob. 0.76 Best val. 0.46 Best dist. 1.18 Best context 0.39
#
# i_sample/N_samples: 9/10
# #epoch 290/300.
# self.alpha: 0.6. self.gamma: 0.1
# Valid True. Best True.
# Pred logits: [0.87,0.13] Target prob [0.5] Target cls 0
# Pred context: [0.43,0.99] Target ctx [[1. 1.]]
# Raw Dist loss 1.19 Val loss 0.33  Context loss 0.42
# Scaled Dist loss 0.12 Val loss 0.20  Context loss 0.17; Loss total 0.45
# Grad mean/abs 0.02/0.07  Grad min/max -0.08/0.11
# Best prob. 0.76 Best val. 0.46 Best dist. 1.18 Best context 0.39
#
# i_sample/N_samples: 9/10
# #epoch 291/300.
# self.alpha: 0.6. self.gamma: 0.1
# Valid True. Best True.
# Pred logits: [0.87,0.13] Target prob [0.5] Target cls 0
# Pred context: [0.44,0.99] Target ctx [[1. 1.]]
# Raw Dist loss 1.19 Val loss 0.33  Context loss 0.42
# Scaled Dist loss 0.12 Val loss 0.20  Context loss 0.17; Loss total 0.45
# Grad mean/abs -0.04/0.07  Grad min/max -0.13/0.05
# Best prob. 0.76 Best val. 0.46 Best dist. 1.18 Best context 0.39
#
# i_sample/N_samples: 9/10
# #epoch 292/300.
# self.alpha: 0.6. self.gamma: 0.1
# Valid True. Best True.
# Pred logits: [0.87,0.13] Target prob [0.5] Target cls 0
# Pred context: [0.43,0.99] Target ctx [[1. 1.]]
# Raw Dist loss 1.20 Val loss 0.33  Context loss 0.42
# Scaled Dist loss 0.12 Val loss 0.20  Context loss 0.17; Loss total 0.45
# Grad mean/abs 0.05/0.09  Grad min/max -0.07/0.14
# Best prob. 0.76 Best val. 0.46 Best dist. 1.18 Best context 0.39
#
# i_sample/N_samples: 9/10
# #epoch 293/300.
# self.alpha: 0.6. self.gamma: 0.1
# Valid True. Best True.
# Pred logits: [0.87,0.13] Target prob [0.5] Target cls 0
# Pred context: [0.44,0.99] Target ctx [[1. 1.]]
# Raw Dist loss 1.19 Val loss 0.33  Context loss 0.42
# Scaled Dist loss 0.12 Val loss 0.20  Context loss 0.17; Loss total 0.46
# Grad mean/abs -0.04/0.11  Grad min/max -0.14/0.15
# Best prob. 0.76 Best val. 0.46 Best dist. 1.18 Best context 0.39
#
# i_sample/N_samples: 9/10
# #epoch 294/300.
# self.alpha: 0.6. self.gamma: 0.1
# Valid True. Best True.
# Pred logits: [0.87,0.13] Target prob [0.5] Target cls 0
# Pred context: [0.43,0.99] Target ctx [[1. 1.]]
# Raw Dist loss 1.19 Val loss 0.33  Context loss 0.42
# Scaled Dist loss 0.12 Val loss 0.20  Context loss 0.17; Loss total 0.45
# Grad mean/abs 0.02/0.07  Grad min/max -0.08/0.11
# Best prob. 0.76 Best val. 0.46 Best dist. 1.18 Best context 0.39
#
# i_sample/N_samples: 9/10
# #epoch 295/300.
# self.alpha: 0.6. self.gamma: 0.1
# Valid True. Best True.
# Pred logits: [0.87,0.13] Target prob [0.5] Target cls 0
# Pred context: [0.44,0.99] Target ctx [[1. 1.]]
# Raw Dist loss 1.19 Val loss 0.33  Context loss 0.42
# Scaled Dist loss 0.12 Val loss 0.20  Context loss 0.17; Loss total 0.45
# Grad mean/abs -0.04/0.07  Grad min/max -0.13/0.05
# Best prob. 0.76 Best val. 0.46 Best dist. 1.18 Best context 0.39
#
# i_sample/N_samples: 9/10
# #epoch 296/300.
# self.alpha: 0.6. self.gamma: 0.1
# Valid True. Best True.
# Pred logits: [0.87,0.13] Target prob [0.5] Target cls 0
# Pred context: [0.43,0.99] Target ctx [[1. 1.]]
# Raw Dist loss 1.20 Val loss 0.33  Context loss 0.42
# Scaled Dist loss 0.12 Val loss 0.20  Context loss 0.17; Loss total 0.45
# Grad mean/abs 0.05/0.09  Grad min/max -0.07/0.14
# Best prob. 0.76 Best val. 0.46 Best dist. 1.18 Best context 0.39
#
# i_sample/N_samples: 9/10
# #epoch 297/300.
# self.alpha: 0.6. self.gamma: 0.1
# Valid True. Best True.
# Pred logits: [0.87,0.13] Target prob [0.5] Target cls 0
# Pred context: [0.44,0.99] Target ctx [[1. 1.]]
# Raw Dist loss 1.19 Val loss 0.33  Context loss 0.42
# Scaled Dist loss 0.12 Val loss 0.20  Context loss 0.17; Loss total 0.45
# Grad mean/abs -0.04/0.11  Grad min/max -0.14/0.15
# Best prob. 0.76 Best val. 0.46 Best dist. 1.18 Best context 0.39
#
# i_sample/N_samples: 9/10
# #epoch 298/300.
# self.alpha: 0.6. self.gamma: 0.1
# Valid True. Best True.
# Pred logits: [0.87,0.13] Target prob [0.5] Target cls 0
# Pred context: [0.43,0.99] Target ctx [[1. 1.]]
# Raw Dist loss 1.20 Val loss 0.33  Context loss 0.42
# Scaled Dist loss 0.12 Val loss 0.20  Context loss 0.17; Loss total 0.45
# Grad mean/abs 0.05/0.09  Grad min/max -0.07/0.14
# Best prob. 0.76 Best val. 0.46 Best dist. 1.18 Best context 0.39
#
# i_sample/N_samples: 9/10
# #epoch 299/300.
# self.alpha: 0.6. self.gamma: 0.1
# Valid True. Best True.
# Pred logits: [0.87,0.13] Target prob [0.5] Target cls 0
# Pred context: [0.44,0.99] Target ctx [[1. 1.]]
# Raw Dist loss 1.19 Val loss 0.33  Context loss 0.42
# Scaled Dist loss 0.12 Val loss 0.20  Context loss 0.17; Loss total 0.45
# Grad mean/abs -0.04/0.07  Grad min/max -0.13/0.04
# Best prob. 0.76 Best val. 0.46 Best dist. 1.18 Best context 0.39
#
# i_sample/N_samples: 9/10
# #epoch 300/300.
# self.alpha: 0.6. self.gamma: 0.1
# Valid True. Best True.
# Pred logits: [0.87,0.13] Target prob [0.5] Target cls 0
# Pred context: [0.43,0.99] Target ctx [[1. 1.]]
# Raw Dist loss 1.20 Val loss 0.33  Context loss 0.42
# Scaled Dist loss 0.12 Val loss 0.20  Context loss 0.17; Loss total 0.45
# Grad mean/abs 0.02/0.07  Grad min/max -0.08/0.11
# Best prob. 0.76 Best val. 0.46 Best dist. 1.18 Best context 0.39

# %% [markdown]
# # Heat map $\Delta(x)$ (with normalized data)
# Delta heatmap without dernormalizing the data

# %%
## Setting up data
# Original samples "scaled"
print(X_original.shape)
# List for all CF generated in all exps
print(len(X_cf_list))
# List of exps
print([exp["name"] for exp in EXP])
# List of feats
print(data.features_lbls)
# Original samples 
X_original_unscaled = data.scaler_inverse_transform(X_original)
# Denormalized CF samples 
X_cf_unscaled_list = [data.scaler_inverse_transform(x_cf)  for x_cf in X_cf_list]
# Out:
# (10, 9)
# 5
# ['LatentCF++', 'Prototype C', 'Prototype D', 'CACTUS', 'CausalCACTUS']
# ['lsat', 'ugpa', 'zfygpa', 'zgpa', 'faminc', 'decile1b', 'decile3', 'fulltime', 'tier']

# %%
import seaborn as sns

# -----------------------------
# Compute aggregated |Δx|
# -----------------------------

feature_names = ['LSAT Score',
                    'Undergrad GPA',
                    '1L GPA',
                    'Overall GPA',
                    'Family Income',
                    'LSAT Decile',
                    'Class Decile',
                    'Enrollment',
                    'Tier']


exp_names = ["LatentCF++", "Prototype C","Prototype D","CACTUS","CausalCAC"]

agg_deltas = []

for x_cf in X_cf_list:
    delta = np.abs(x_cf - X_original)   # |Δx|
    agg_deltas.append(delta.mean(axis=0))        # aggregate over samples
    

# Shape: (num_experiments, num_features)
agg_deltas = np.vstack(agg_deltas)
agg_deltas = np.round(agg_deltas,2)
# Create DataFrame (features as rows, experiments as columns)
df_heatmap = pd.DataFrame(
    agg_deltas.T,
    index=feature_names,
    columns=exp_names
)

# -----------------------------
# Seaborn / Matplotlib paper style
# -----------------------------
sns.set_theme(
    context="paper",
    style="white",
    font_scale=1.4   # escala global (ajustable)
)

# -----------------------------
# Plot heatmap
# -----------------------------
plt.figure(figsize=(10, 6))

ax = sns.heatmap(
    df_heatmap,
    cmap="YlOrRd",
    annot=True,
    fmt=".2f",
    linewidths=0.5,
    cbar_kws={"label": "Mean |Δx|"},
    annot_kws={"size": 12}   # números dentro del heatmap
)


# Tick labels
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    ha="right",
    fontsize=15
)

ax.set_yticklabels(
    ax.get_yticklabels(),
    rotation=0,
    fontsize=15
)

# Colorbar label & ticks
cbar = ax.collections[0].colorbar
cbar.set_label("Mean |Δx|", fontsize=15)
cbar.ax.tick_params(labelsize=12)

plt.tight_layout()
plt.show()

#TODO indicate the graph structure in the Heatmap

# %%
# strict digraph {
# NumberRealEstateLoansOrLines;
# NumberOfTimes90DaysLate;
# NumberOfDependents;
# age;
# DebtRatio;
# NumberOfTime3059DaysPastDueNotWorse;
# NumberOfOpenCreditLinesAndLoans;
# RevolvingUtilizationOfUnsecuredLines;
# MonthlyIncome;
# NumberOfTime6089DaysPastDueNotWorse;
# NumberOfTimes90DaysLate -> NumberOfOpenCreditLinesAndLoans;
# NumberOfTimes90DaysLate -> NumberRealEstateLoansOrLines;
# NumberOfTimes90DaysLate -> RevolvingUtilizationOfUnsecuredLines;
# NumberOfTimes90DaysLate -> MonthlyIncome;
# NumberOfTime3059DaysPastDueNotWorse -> NumberOfOpenCreditLinesAndLoans;
# NumberOfTime3059DaysPastDueNotWorse -> NumberRealEstateLoansOrLines;
# NumberOfTime3059DaysPastDueNotWorse -> MonthlyIncome;
# NumberOfOpenCreditLinesAndLoans -> DebtRatio;
# RevolvingUtilizationOfUnsecuredLines -> NumberOfOpenCreditLinesAndLoans;
# MonthlyIncome -> NumberOfOpenCreditLinesAndLoans;
# }

# %%
print(child_to_parents_dict)
for i,feat in enumerate(feature_names):
    print(f"{i}:{feat}")
# Out:
# {4: [7], 6: [1], 5: [0]}
# 0:LSAT Score
# 1:Undergrad GPA
# 2:1L GPA
# 3:Overall GPA
# 4:Family Income
# 5:LSAT Decile
# 6:Class Decile
# 7:Enrollment
# 8:Tier

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import spearmanr
from matplotlib.patches import Rectangle
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

# -----------------------------
# Setup
# -----------------------------
feature_names = ['LSAT Score',
                    'Undergrad GPA',
                    '1L GPA',
                    'Overall GPA',
                    'Family Income',
                    'LSAT Decile',
                    'Class Decile',
                    'Enrollment',
                    'Tier']

exp_names = ["LatentCF++", "Prototype C","Prototype D","CACTUS","CausalCAC"]
d = X_original_unscaled.shape[1]

# Build list of (row, col) indices to highlight
highlight_pairs = []
for child, parents in child_to_parents_dict.items():
    for parent in parents:
        highlight_pairs.append((child, parent))   # (row=child, col=parent)
        highlight_pairs.append((parent, child))   # symmetric cell
highlight_pairs = list(set(highlight_pairs))      # remove duplicates

# -----------------------------
# Compute |Spearman| correlation matrices
# -----------------------------
corr_mats = []
for x_cf in X_cf_list:
    delta = x_cf - X_original
    corr, _ = spearmanr(delta, axis=0)
    corr = np.asarray(corr).reshape(d, d)
    C = np.abs(corr)
    np.fill_diagonal(C, 0.0)
    corr_mats.append(C)

# -----------------------------
# Plot (5 matrices) + colorbar in subplot 6
# -----------------------------
sns.set(style="white")

fig, axes = plt.subplots(
    2, 3,
    figsize=(14, 8),
    gridspec_kw={"wspace": 0.0, "hspace": 0.1}
)
axes = axes.flatten()

cmap = "YlOrRd"
vmin, vmax = 0.0, 1.0

# Plot only the first 5 heatmaps (leave axes[5] for the colorbar)
for i, (ax, name, C) in enumerate(zip(axes[:5], exp_names, corr_mats)):
    sns.heatmap(
        C,
        ax=ax,
        cmap=cmap,
        vmin=vmin,
        vmax=vmax,
        square=True,
        xticklabels=feature_names if i >= 2 else False,       # bottom row only
        yticklabels=feature_names if i % 3 == 0 else False,   # leftmost col only
        cbar=False,
        linewidths=0.3,
        linecolor="white",
    )

    # Highlight child-parent cells with rectangles
    for (r, c) in highlight_pairs:
        if 0 <= r < d and 0 <= c < d:
            ax.add_patch(
                Rectangle(
                    (c, r), 1, 1,
                    fill=False,
                    edgecolor="black",
                    linewidth=2.5
                )
            )

    if i >= 2:
        ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha="right")

    ax.set_title(name, fontsize=16)
    ax.tick_params(axis="x", labelsize=14)
    ax.tick_params(axis="y", labelsize=14)

# -----------------------------
# Put a THIN horizontal colorbar inside the 6th subplot (axes[5])
# -----------------------------
axes[5].axis("off")  # use only as a container

mappable = axes[0].collections[0]

# inset axis for a thin bar (won't cover subplot 3 xticks)
cax = inset_axes(
    axes[5],
    width="90%",      # relative to subplot 6
    height="15%",     # thin bar
    loc="lower center",
    borderpad=0.0
)

cbar = fig.colorbar(
    mappable,
    cax=cax,
    orientation="horizontal"
)

cbar.set_label(r"$|\rho_s(\Delta x_i,\Delta x_j)|$", fontsize=14, labelpad=6)
cbar.ax.tick_params(labelsize=12)

#plt.tight_layout()
plt.show()

# %%
# strict digraph {
# NumberRealEstateLoansOrLines;
# NumberOfTimes90DaysLate;
# NumberOfDependents;
# age;
# DebtRatio;
# NumberOfTime3059DaysPastDueNotWorse;
# NumberOfOpenCreditLinesAndLoans;
# RevolvingUtilizationOfUnsecuredLines;
# MonthlyIncome;
# NumberOfTime6089DaysPastDueNotWorse;
# NumberOfTimes90DaysLate -> NumberOfOpenCreditLinesAndLoans;
# NumberOfTimes90DaysLate -> NumberRealEstateLoansOrLines;
# NumberOfTimes90DaysLate -> RevolvingUtilizationOfUnsecuredLines;
# NumberOfTimes90DaysLate -> MonthlyIncome;
# NumberOfTime3059DaysPastDueNotWorse -> NumberOfOpenCreditLinesAndLoans;
# NumberOfTime3059DaysPastDueNotWorse -> NumberRealEstateLoansOrLines;
# NumberOfTime3059DaysPastDueNotWorse -> MonthlyIncome;
# NumberOfOpenCreditLinesAndLoans -> DebtRatio;
# RevolvingUtilizationOfUnsecuredLines -> NumberOfOpenCreditLinesAndLoans;
# MonthlyIncome -> NumberOfOpenCreditLinesAndLoans;
# }
